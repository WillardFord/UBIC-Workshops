# %% [markdown]
# # Gene Regulation
#
#
# ## Transcription Factors
#
# Proteins (genes) that turn on other genes
#
# Motivating Problem:
# ---
# [MIT Opencourseware Notes](https://ocw.mit.edu/courses/7-91j-foundations-of-computational-and-systems-biology-spring-2014/resources/mit7_91js14_lecture15/) (Slide 108 has great figure)
#
# Given a set of gene expression levels, how can we determine which transcription factor caused the difference in expression levels?
#
# ## Probability and Bayes Rule
#
# ## Bayesian Networks
# Good lecture notes for [Bayesian Networks](https://cs50.harvard.edu/ai/2024/notes/2/)
#
# ## Gene Regulation Network
#
# 1. Real rna expression data
# 2. Methods
#   1. Real ground truth (known interactions and known not-interacting)
#   2. Correlated Expression levels
#     1. Distance metric (euclidean distance or other) or something else
# 3. Calculate network and generate probabilities.
#   1. Simulated data with different interactions to see how well we can impute them
#
# Log likelihood interaction thresholds
#
# Massive Network: http://www.sciencedirect.com/science/article/pii/S0092867411011524
#
# ## Applications
#
#
# ## Labs at UCSD doing similar work
#
#
# [Ideker Lab](https://idekerlab.ucsd.edu/)
#
# [Wang lab](http://wanglab.ucsd.edu/)
#
# [Ay Lab (La Jolla Institute for Immunology)](https://www.lji.org/labs/ay/)
#
# [Boolean Lab (Sahoo)](https://sites.google.com/view/debashis-sahoo/)
